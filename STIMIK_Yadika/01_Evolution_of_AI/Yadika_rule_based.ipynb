# %%
def simple_chatbot(user_input):
      rules = {
          "hello": "Hi there! How can I help you?",
          "sad": "I'm sorry to hear that. Why do you feel sad?",
          "happy": "That's great! What makes you happy?",
          "bye": "Goodbye! Have a nice day!"
      }

      for keyword, response in rules.items():
          if keyword in user_input.lower():
              return response
      return "I don't understand. Can you rephrase?"

# %%
print(simple_chatbot("I am feeling sad today"))
# Out:
# I'm sorry to hear that. Why do you feel sad?
